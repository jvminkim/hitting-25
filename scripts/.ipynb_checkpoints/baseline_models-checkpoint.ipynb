# %%
import arviz as az
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import seaborn.objects as so
import numpy as np
import pandas as pd
import polars as pl
import pymc as pm
import pytensor.tensor as pt

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

RANDOM_SEED = 504

print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v5.19.1

# %%
from retrieve_sql_module import get_pbp_data

years = list(range(2021,2025))
pbp_data = get_pbp_data(years, 0)
# Out:
# D:\jamin\baseball-projects\projections\hitting\scripts\retrieve_sql_module.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pbp_data = pd.concat(pbp_data_list, ignore_index=True)

# %%
pbp_data
# Out:
#         pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0               FF 2021-10-03           92.3           1.40           6.80
# 1               SL 2021-10-03           80.6           1.60           6.64
# 2               CU 2021-10-03           75.5           1.46           6.88
# 3               CU 2021-10-03           75.0           1.53           6.83
# 4               FF 2021-10-03           91.2           1.49           6.66
# ...            ...        ...            ...            ...            ...
# 2891004         FF 2024-03-20           95.7          -2.13           5.77
# 2891005         SI 2024-03-20           93.9          -2.17           5.70
# 2891006         SI 2024-03-20           93.4          -2.00           5.70
# 2891007         FF 2024-03-20           92.6          -1.94           5.83
# 2891008         FF 2024-03-20           94.5          -1.79           5.83
#
#          player_name  batter  pitcher     events    description  ...  \
# 0        Smith, Will  596019   519293  field_out  hit_into_play  ...
# 1        Smith, Will  596019   519293       None           foul  ...
# 2        Smith, Will  596019   519293       None           foul  ...
# 3        Smith, Will  596019   519293       None           ball  ...
# 4        Smith, Will  607043   519293  field_out  hit_into_play  ...
# ...              ...     ...      ...        ...            ...  ...
# 2891004  Darvish, Yu  660271   506433       None           ball  ...
# 2891005  Darvish, Yu  605141   506433       None           ball  ...
# 2891006  Darvish, Yu  605141   506433       None           ball  ...
# 2891007  Darvish, Yu  605141   506433       None           foul  ...
# 2891008  Darvish, Yu  605141   506433       None           ball  ...
#
#         n_thruorder_pitcher n_priorpa_thisgame_player_at_bat  \
# 0                         1                                3
# 1                         1                                3
# 2                         1                                3
# 3                         1                                3
# 4                         1                                3
# ...                     ...                              ...
# 2891004                   1                                0
# 2891005                   1                                0
# 2891006                   1                                0
# 2891007                   1                                0
# 2891008                   1                                0
#
#         pitcher_days_since_prev_game batter_days_since_prev_game  \
# 0                                3.0                         1.0
# 1                                3.0                         1.0
# 2                                3.0                         1.0
# 3                                3.0                         1.0
# 4                                3.0                         1.0
# ...                              ...                         ...
# 2891004                          NaN                         NaN
# 2891005                          NaN                         NaN
# 2891006                          NaN                         NaN
# 2891007                          NaN                         NaN
# 2891008                          NaN                         NaN
#
#          pitcher_days_until_next_game batter_days_until_next_game  \
# 0                                 6.0                         NaN
# 1                                 6.0                         NaN
# 2                                 6.0                         NaN
# 3                                 6.0                         NaN
# 4                                 6.0                         NaN
# ...                               ...                         ...
# 2891004                           8.0                         1.0
# 2891005                           8.0                         1.0
# 2891006                           8.0                         1.0
# 2891007                           8.0                         1.0
# 2891008                           8.0                         1.0
#
#         api_break_z_with_gravity api_break_x_arm api_break_x_batter_in  \
# 0                           1.28            0.69                 -0.69
# 1                           2.99           -0.77                  0.77
# 2                           4.52           -0.65                  0.65
# 3                           4.74           -0.69                  0.69
# 4                           1.49            0.63                  0.63
# ...                          ...             ...                   ...
# 2891004                     1.03            0.54                 -0.54
# 2891005                     1.57            1.34                  1.34
# 2891006                     1.63            1.42                  1.42
# 2891007                     1.11            0.25                  0.25
# 2891008                     1.12            0.52                  0.52
#
#         arm_angle
# 0            47.4
# 1            44.3
# 2            51.7
# 3            49.5
# 4            44.0
# ...           ...
# 2891004       NaN
# 2891005       NaN
# 2891006       NaN
# 2891007       NaN
# 2891008       NaN
#
# [2891009 rows x 113 columns]

# %%
grouped = pbp_data.groupby('batter').size()

# %%
grouped.sort_values(ascending=False)
# Out:
# batter
# 621566    11847
# 665742    11550
# 543760    11453
# 656941    11115
# 502671    11068
#           ...
# 676332        1
# 682653        1
# 700341        1
# 699305        1
# 681580        1
# Length: 1948, dtype: int64
