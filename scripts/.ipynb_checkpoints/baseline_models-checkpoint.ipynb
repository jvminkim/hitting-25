# %%
import arviz as az
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import seaborn.objects as so
import numpy as np
import pandas as pd
import polars as pl
import pymc as pm
import pytensor as pt
import pybaseball 
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
#import xgboost as xgb

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

RANDOM_SEED = 504

print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v5.19.1

# %%
from retrieve_sql_module import get_events_data
events_data_2024 = get_events_data("2024")

# %%
events_data_2024
# Out:
#        pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0              KC 2024-10-30           77.5          -1.11           5.65
# 1              KC 2024-10-30           77.4          -1.23           5.78
# 2              KC 2024-10-30           77.6          -1.08           5.75
# 3              ST 2024-10-30           79.4          -1.48           5.81
# 4              CU 2024-10-30           75.5          -1.14           6.05
# ...           ...        ...            ...            ...            ...
# 192067         FF 2024-03-20           96.6          -1.69           6.17
# 192068         FF 2024-03-20           96.9          -1.74           6.05
# 192069         FF 2024-03-20           94.5          -1.91           5.67
# 192070         SI 2024-03-20           95.4          -2.11           5.61
# 192071         FS 2024-03-20           91.1          -2.05           5.58
#
#              player_name  batter  pitcher     events              description  \
# 0        Buehler, Walker  657077   621111  strikeout  swinging_strike_blocked
# 1        Buehler, Walker  669224   621111  strikeout          swinging_strike
# 2        Buehler, Walker  683011   621111  field_out            hit_into_play
# 3       Leiter Jr., Mark  669257   643410  field_out            hit_into_play
# 4       Leiter Jr., Mark  669242   643410  strikeout          swinging_strike
# ...                  ...     ...      ...        ...                      ...
# 192067    Glasnow, Tyler  665487   607192  field_out            hit_into_play
# 192068    Glasnow, Tyler  593428   607192  field_out            hit_into_play
# 192069       Darvish, Yu  669257   506433  field_out            hit_into_play
# 192070       Darvish, Yu  518692   506433  strikeout            called_strike
# 192071       Darvish, Yu  660271   506433  force_out            hit_into_play
#
#         ... field_error_n sac_fly_n n_pitches total_events  single_rate  \
# 0       ...             5        11      2605          684     0.141813
# 1       ...             2         7      1894          481     0.112266
# 2       ...             5         3      3101          754     0.159151
# 3       ...             3         9      2568          608     0.125000
# 4       ...             2         3       808          220     0.154545
# ...     ...           ...       ...       ...          ...          ...
# 192067  ...             0         1      1669          471     0.150743
# 192068  ...             2         6      1922          490     0.179592
# 192069  ...             3         9      2568          608     0.125000
# 192070  ...             3         8      2759          690     0.147826
# 192071  ...             3         5      3180          799     0.135169
#
#        double_rate triple_rate home_run_rate strikeout_rate field_out_rate
# 0         0.043860    0.001462      0.141813       0.144737       0.543860
# 1         0.041580    0.002079      0.112266       0.232848       0.438669
# 2         0.039788    0.009284      0.159151       0.225464       0.468170
# 3         0.041118    0.003289      0.125000       0.190789       0.481908
# 4         0.045455    0.004545      0.154545       0.177273       0.490909
# ...            ...         ...           ...            ...            ...
# 192067    0.050955    0.002123      0.150743       0.208068       0.439490
# 192068    0.034694    0.002041      0.179592       0.167347       0.516327
# 192069    0.041118    0.003289      0.125000       0.190789       0.481908
# 192070    0.052174    0.004348      0.147826       0.159420       0.466667
# 192071    0.048811    0.008761      0.135169       0.234043       0.379224
#
# [192072 rows x 136 columns]

# %%
events_data_2024["description"].unique()
# Out:
# array(['field_out', 'single', 'home_run', 'double', 'triple', 'foul',
#        'swinging_strike', 'ball', 'called_strike'], dtype=object)

# %%
coords = {
    "category": events_data_2024["description"].unique().tolist(),
    "batter": events_data_2024["batter"].unique().tolist()
}

# %%
description, unique_categories = pd.factorize(events_data_2024["description"], sort = True)

# %%
coords =  {
    "category" : unique_categories.tolist(),
    "batter" : events_data_2024["batter"].unique().tolist()  
}

# %%
with pm.Model(coords=coords) as uninformative_prior_model:
    p = pm.Dirichlet("P", a=np.ones(len(coords["category"])), dims=('batter', 'category'))

    y = pm.Categorical("y", p = p, observed = description, dims = "batter")
pm.model_to_graphviz(uninformative_prior_model)
